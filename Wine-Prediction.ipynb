# %%
##Wine-Prediction
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Data Preprocessing

# %%
data = pd.read_csv('winequality-red.csv')
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# Size of Data file

# %%
data.shape
# Out:
# (1599, 12)

# %% [markdown]
# Checking for missing values

# %%
data.isnull().sum()
#There are no null values quite clean data set
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Distribution of quality variable ie our target variable
plt.hist(data['quality'],bins=5)
plt.show()

# %% [markdown]
# Checking Correlations of variables

# %%
sns.pairplot(data)

# %%
#No of good observations and bad observations

print(len(data[data['quality']>6]))
print(len(data[data['quality']>5]))
# Out:
# 217
# 855

# %%
def binary_converter():
    for i in range(len(data['quality'])):
        if data['quality'][i]>5:
            data['quality'][i] = 1
        else:
            data['quality'][i] = 0
        # print(i)
binary_converter()
# Out:
# c:\users\tushar saxena\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\users\tushar saxena\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
data['quality'].value_counts()
# Out:
# 1    855
# 0    744
# Name: quality, dtype: int64
